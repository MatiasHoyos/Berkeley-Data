# %%
#Import commands and libraries for code to work 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
#reading the file
df = pd.read_csv ("sub-data.csv")
df.head()
#determining the x and y axis for the scatter graph                 
x = "ASSET"
Y = "DEBT"
#plotting the scatter graph with the information/variables that i choose
plt.scatter(x = df[x], y= df[Y])
plt.title("Assets in Comparisson to debt")
# Out:
# Text(0.5, 1.0, 'Assets in Comparisson to debt')
